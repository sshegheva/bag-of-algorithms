# %%
# %matplotlib inline

# %%
from algo_evaluation.optimization.problems.schedule_problem import schedulecost, people, printschedule

# %%
from algo_evaluation.optimization import hill_climbing as hc
reload(hc)
# Out:
# <module 'algo_evaluation.optimization.hill_climbing' from '/Users/maestro/schoolspace/bag-of-algorithms/algo_evaluation/optimization/hill_climbing.pyc'>

# %%
from algo_evaluation.optimization import simulated_annealing as sa
reload(sa)
# Out:
# <module 'algo_evaluation.optimization.simulated_annealing' from '/Users/maestro/schoolspace/bag-of-algorithms/algo_evaluation/optimization/simulated_annealing.py'>

# %%
df = hc.evaluate_rhc()

# %%
df.set_index('evaluations')['optimal_value'].plot()

# %%
import seaborn as sns

# %%
sns.lmplot('evaluations', 'cost', data=df)

# %%
df_sa = sa.evaluate_sa()

# %%
df_sa.set_index('temperature')['optimal_value'].plot()

# %%
df_sa
# Out:
#       temperature  cost  optimal_value
# 0    10000.000000  6983       0.000143
# 1     9500.000000  6627       0.000151
# 2     9025.000000  6498       0.000154
# 3     8573.750000  6498       0.000154
# 4     8145.062500  6498       0.000154
# 5     7737.809375  5915       0.000169
# 6     7350.918906  5287       0.000189
# 7     6983.372961  5287       0.000189
# 8     6634.204313  5287       0.000189
# 9     6302.494097  5287       0.000189
# 10    5987.369392  5469       0.000183
# 11    5688.000923  5287       0.000189
# 12    5403.600877  5369       0.000186
# 13    5133.420833  5287       0.000189
# 14    4876.749791  5287       0.000189
# 15    4632.912302  5369       0.000186
# 16    4401.266687  5287       0.000189
# 17    4181.203352  5287       0.000189
# 18    3972.143185  5287       0.000189
# 19    3773.536025  4962       0.000202
# 20    3584.859224  5355       0.000187
# 21    3405.616263  4962       0.000202
# 22    3235.335450  4774       0.000209
# ...

# %%
from algo_evaluation.optimization import genetic_optimize as ga
reload(ga)
# Out:
# <module 'algo_evaluation.optimization.genetic_optimize' from '/Users/maestro/schoolspace/bag-of-algorithms/algo_evaluation/optimization/genetic_optimize.py'>

# %%
df_ga = ga.evaluate_ga()

# %%
df_ga.set_index('iterations')['optimal_value'].plot()

# %%
# %matplotlib inline
import pandas as pd
pd.set_option('display.max_columns', 15)
pd.set_option('display.line_width', 400)
pd.set_option('display.mpl_style', 'default')
from algorithms.decision_tree import DecisionTree
from algorithms.datasets import load_higgs_train
from sklearn.cross_validation import train_test_split
from sklearn.metrics import accuracy_score
import numpy as np
import matplotlib.pyplot as plt
# Out:
# line_width has been deprecated, use display.width instead (currently both are
# identical)

# %%
dt = DecisionTree()
# Out:
# INFO:algorithms:Loaded higgs training dataset of size 68114

# %%
dt.train()
# Out:
# INFO:algorithms:Trained decision tree classifier

# %%
dt.predict()
# Out:
# INFO:algorithms:Generated predictions

# %%
dt.predictions
# Out:
# array(['s', 's', 'b', ..., 'b', 's', 's'], dtype=object)

# %%
dt.evaluate()
# Out:
# INFO:algorithms:Accuracy score 0.773289438562
# INFO:algorithms:Accuracy score = 0.773289438562

# %%
# Parameters
n_classes = 2
plot_colors = "br"
plot_step = 0.02

# %%
# Plot the training points
X = dt.features_train[:, [0,1]]
Y = dt.labels_train
for i, color in zip(set(Y), plot_colors):
    idx = np.where(Y == i)
    plt.scatter(X[idx, 0], X[idx, 1], c=color, label=i, cmap=plt.cm.Paired)
plt.legend()

# %%
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),
                         np.arange(y_min, y_max, plot_step))
zz = np.array([1 if p=='s' else 0 for p in predictions])
cs = plt.contourf(xx, yy, zz, cmap=plt.cm.Paired)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-eda0e37b9924> in <module>()
#       4                          np.arange(y_min, y_max, plot_step))
#       5 zz = np.array([1 if p=='s' else 0 for p in predictions])
# ----> 6 cs = plt.contourf(xx, yy, zz, cmap=plt.cm.Paired)
#
# /Users/maestro/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in contourf(*args, **kwargs)
#    2710         ax.hold(hold)
#    2711     try:
# -> 2712         ret = ax.contourf(*args, **kwargs)
#    2713         draw_if_interactive()
#    2714     finally:
#
# /Users/maestro/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in contourf(self, *args, **kwargs)
#    5323             self.cla()
#    5324         kwargs['filled'] = True
# -> 5325         return mcontour.QuadContourSet(self, *args, **kwargs)
#    5326     contourf.__doc__ = mcontour.QuadContourSet.contour_doc
#    5327
#
# /Users/maestro/anaconda/lib/python2.7/site-packages/matplotlib/contour.pyc in __init__(self, ax, *args, **kwargs)
#    1426         are described in QuadContourSet.contour_doc.
#    1427         """
# -> 1428         ContourSet.__init__(self, ax, *args, **kwargs)
#    1429
#    1430     def _process_args(self, *args, **kwargs):
#
# /Users/maestro/anaconda/lib/python2.7/site-packages/matplotlib/contour.pyc in __init__(self, ax, *args, **kwargs)
#     872         self._transform = kwargs.get('transform', None)
#     873
# --> 874         self._process_args(*args, **kwargs)
#     875         self._process_levels()
#     876
#
# /Users/maestro/anaconda/lib/python2.7/site-packages/matplotlib/contour.pyc in _process_args(self, *args, **kwargs)
#    1439             self.zmax = args[0].zmax
#    1440         else:
# -> 1441             x, y, z = self._contour_args(args, kwargs)
#    1442
#    1443             _mask = ma.getmask(z)
#
# /Users/maestro/anaconda/lib/python2.7/site-packages/matplotlib/contour.pyc in _contour_args(self, args, kwargs)
#    1503             args = args[1:]
#    1504         elif Nargs <= 4:
# -> 1505             x, y, z = self._check_xyz(args[:3], kwargs)
#    1506             args = args[3:]
#    1507         else:
#
# /Users/maestro/anaconda/lib/python2.7/site-packages/matplotlib/contour.pyc in _check_xyz(self, args, kwargs)
#    1537
#    1538         if z.ndim != 2:
# -> 1539             raise TypeError("Input z must be a 2D array.")
#    1540         else:
#    1541             Ny, Nx = z.shape
#
# TypeError: Input z must be a 2D array.

# %%
zz = np.array([1 if p=='s' else 0 for p in predictions])
zz.reshape(xx.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-1412224afa97> in <module>()
#       1 zz = np.array([1 if p=='s' else 0 for p in predictions])
# ----> 2 zz.reshape(xx.shape)
#
# ValueError: total size of new array must be unchanged

# %%
xx.shape
# Out:
# (20952, 48616)

# %%
zz.shape
# Out:
# (22478,)

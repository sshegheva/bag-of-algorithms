# %%
# %matplotlib inline
import pandas as pd
pd.set_option('display.max_columns', 15)
pd.set_option('display.line_width', 400)
pd.set_option('display.mpl_style', 'default')
from algorithms.decision_tree import DecisionTree, estimate_best_min_samples_split, estimate_best_max_depth, load_higgs_train
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
import sklearn
sklearn.__version__
# Out:
# line_width has been deprecated, use display.width instead (currently both are
# identical)
# '0.15.2'

# %%
data = load_higgs_train()
dt = DecisionTree(data=data)
dt.train()
dt.predict()
dt.evaluate()
# Out:
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:All features Index([u'DER_mass_MMC', u'DER_mass_transverse_met_lep', u'DER_mass_vis', u'DER_pt_h', u'DER_deltaeta_jet_jet', u'DER_mass_jet_jet', u'DER_prodeta_jet_jet', u'DER_deltar_tau_lep', u'DER_pt_tot', u'DER_sum_pt', u'DER_pt_ratio_lep_tau', u'DER_met_phi_centrality', u'DER_lep_eta_centrality', u'PRI_tau_pt', u'PRI_tau_eta', u'PRI_tau_phi', u'PRI_lep_pt', u'PRI_lep_eta', u'PRI_lep_phi', u'PRI_met', u'PRI_met_phi', u'PRI_met_sumet', u'PRI_jet_num', u'PRI_jet_leading_pt', u'PRI_jet_leading_eta', u'PRI_jet_leading_phi', u'PRI_jet_subleading_pt', u'PRI_jet_subleading_eta', u'PRI_jet_subleading_phi', u'PRI_jet_all_pt', u'Weight', u'Label'], dtype='object')
# INFO:algorithms:Pruned features ['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis', 'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet', 'DER_prodeta_jet_jet', 'DER_deltar_tau_lep']
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.883775966342
# INFO:algorithms:Test Accuracy score = 0.782053563484

# %%
dt.feature_names
# Out:
# ['DER_mass_MMC',
#  'DER_mass_transverse_met_lep',
#  'DER_mass_vis',
#  'DER_pt_h',
#  'DER_deltaeta_jet_jet',
#  'DER_mass_jet_jet',
#  'DER_prodeta_jet_jet',
#  'DER_deltar_tau_lep',
#  'DER_pt_tot',
#  'DER_sum_pt',
#  'DER_pt_ratio_lep_tau',
#  'DER_met_phi_centrality',
#  'DER_lep_eta_centrality']

# %%
# Parameters
n_classes = 2
plot_colors = "br"
plot_step = 0.02
# Plot the decision boundary
plt.close()

# %%
def plot_training_points(feature_group, plot_number):
    plt.figure(figsize=(20,20))
    plt.subplot(len(dt.feature_names), 1, plot_number)
    feature_1, feature_2 = feature_group
    X = dt.features_train[:, [dt.feature_names.index(feature_1),dt.feature_names.index(feature_2)]]
    Y = dt.labels_train
    for i, color in zip(set(Y), plot_colors):
        idx = np.where(Y == i)
        plt.scatter(X[idx, 0], X[idx, 1], c=color, label=i, cmap=plt.cm.Paired)

    plt.xlabel(feature_1)
    plt.ylabel(feature_2)
    plt.axis("tight")
    plt.legend()

# %%
i = 1
for feature_1, feature_2 in zip(dt.feature_names[:-1], dt.feature_names[1:]):
    plot_training_points([feature_1, feature_2], i)
    i += 1

# %%
#x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
#y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
#xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),
#                         np.arange(y_min, y_max, plot_step))
#zz = np.array([1 if p=='s' else 0 for p in dt.predictions])
#cs = plt.contourf(xx, yy, zz, cmap=plt.cm.Paired)

# %%
df = estimate_best_min_samples_split()
# Out:
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:All features Index([u'DER_mass_MMC', u'DER_mass_transverse_met_lep', u'DER_mass_vis', u'DER_pt_h', u'DER_deltaeta_jet_jet', u'DER_mass_jet_jet', u'DER_prodeta_jet_jet', u'DER_deltar_tau_lep', u'DER_pt_tot', u'DER_sum_pt', u'DER_pt_ratio_lep_tau', u'DER_met_phi_centrality', u'DER_lep_eta_centrality', u'PRI_tau_pt', u'PRI_tau_eta', u'PRI_tau_phi', u'PRI_lep_pt', u'PRI_lep_eta', u'PRI_lep_phi', u'PRI_met', u'PRI_met_phi', u'PRI_met_sumet', u'PRI_jet_num', u'PRI_jet_leading_pt', u'PRI_jet_leading_eta', u'PRI_jet_leading_phi', u'PRI_jet_subleading_pt', u'PRI_jet_subleading_eta', u'PRI_jet_subleading_phi', u'PRI_jet_all_pt', u'Weight', u'Label'], dtype='object')
# INFO:algorithms:Pruned features ['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis', 'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet', 'DER_prodeta_jet_jet', 'DER_deltar_tau_lep']
# INFO:algorithms:Created classifier with min_samples_split = 2 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 1.0
# INFO:algorithms:Test Accuracy score = 0.758430465344
# INFO:algorithms:Created classifier with min_samples_split = 4 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.98457358226
# INFO:algorithms:Test Accuracy score = 0.761277693745
# INFO:algorithms:Created classifier with min_samples_split = 6 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.971995792795
# INFO:algorithms:Test Accuracy score = 0.761633597295
# INFO:algorithms:Created classifier with min_samples_split = 8 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.95827855202
# INFO:algorithms:Test Accuracy score = 0.757051339087
# INFO:algorithms:Created classifier with min_samples_split = 10 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.945196774476
# INFO:algorithms:Test Accuracy score = 0.759898567488
# INFO:algorithms:Created classifier with min_samples_split = 12 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.938075203786
# INFO:algorithms:Test Accuracy score = 0.763946970371
# INFO:algorithms:Created classifier with min_samples_split = 14 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.929529318959
# INFO:algorithms:Test Accuracy score = 0.765859951953
# INFO:algorithms:Created classifier with min_samples_split = 16 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.924073100184
# INFO:algorithms:Test Accuracy score = 0.766749710828
# INFO:algorithms:Created classifier with min_samples_split = 18 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.915877815759
# INFO:algorithms:Test Accuracy score = 0.770353234274
# INFO:algorithms:Created classifier with min_samples_split = 20 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.910969410115
# INFO:algorithms:Test Accuracy score = 0.772666607349
# INFO:algorithms:Created classifier with min_samples_split = 22 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.906586905075
# INFO:algorithms:Test Accuracy score = 0.774846516594
# INFO:algorithms:Created classifier with min_samples_split = 24 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.902094837409
# INFO:algorithms:Test Accuracy score = 0.775424859863
# INFO:algorithms:Created classifier with min_samples_split = 26 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.901371724077
# INFO:algorithms:Test Accuracy score = 0.775869739301
# INFO:algorithms:Created classifier with min_samples_split = 28 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.895521079849
# INFO:algorithms:Test Accuracy score = 0.775202420144
# INFO:algorithms:Created classifier with min_samples_split = 30 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.894337803488
# INFO:algorithms:Test Accuracy score = 0.783032298247
# INFO:algorithms:Created classifier with min_samples_split = 32 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.891072837234
# INFO:algorithms:Test Accuracy score = 0.781163804609
# INFO:algorithms:Created classifier with min_samples_split = 34 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.887873608555
# INFO:algorithms:Test Accuracy score = 0.782765370585
# INFO:algorithms:Created classifier with min_samples_split = 36 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.884783942502
# INFO:algorithms:Test Accuracy score = 0.786324406086
# INFO:algorithms:Created classifier with min_samples_split = 38 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.88296520291
# INFO:algorithms:Test Accuracy score = 0.788192899724
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.881168375844
# INFO:algorithms:Test Accuracy score = 0.787347628793
# INFO:algorithms:Created classifier with min_samples_split = 42 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.881584713822
# INFO:algorithms:Test Accuracy score = 0.792953109707
# INFO:algorithms:Created classifier with min_samples_split = 44 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.877355596459
# INFO:algorithms:Test Accuracy score = 0.785345671323
# INFO:algorithms:Created classifier with min_samples_split = 46 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.877180296257
# INFO:algorithms:Test Accuracy score = 0.781386244328
# INFO:algorithms:Created classifier with min_samples_split = 48 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.876698220703
# INFO:algorithms:Test Accuracy score = 0.7890826586
# INFO:algorithms:Created classifier with min_samples_split = 50 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.876040844947
# INFO:algorithms:Test Accuracy score = 0.787258652905
# INFO:algorithms:Created classifier with min_samples_split = 52 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.870694188798
# INFO:algorithms:Test Accuracy score = 0.788860218881
# INFO:algorithms:Created classifier with min_samples_split = 54 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.870168288194
# INFO:algorithms:Test Accuracy score = 0.78636889403
# INFO:algorithms:Created classifier with min_samples_split = 56 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.868524848804
# INFO:algorithms:Test Accuracy score = 0.794198772133
# INFO:algorithms:Created classifier with min_samples_split = 58 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.869664300114
# INFO:algorithms:Test Accuracy score = 0.795488922502
# INFO:algorithms:Created classifier with min_samples_split = 60 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.86703479709
# INFO:algorithms:Test Accuracy score = 0.791796423169
# INFO:algorithms:Created classifier with min_samples_split = 62 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.868963099308
# INFO:algorithms:Test Accuracy score = 0.78743660468
# INFO:algorithms:Created classifier with min_samples_split = 64 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.865741958103
# INFO:algorithms:Test Accuracy score = 0.798158199128
# INFO:algorithms:Created classifier with min_samples_split = 66 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.865303707599
# INFO:algorithms:Test Accuracy score = 0.795133018952
# INFO:algorithms:Created classifier with min_samples_split = 68 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.864076606188
# INFO:algorithms:Test Accuracy score = 0.794154284189
# INFO:algorithms:Created classifier with min_samples_split = 70 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.861753878517
# INFO:algorithms:Test Accuracy score = 0.796912536703
# INFO:algorithms:Created classifier with min_samples_split = 72 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.860329564379
# INFO:algorithms:Test Accuracy score = 0.796423169321
# INFO:algorithms:Created classifier with min_samples_split = 74 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.859453063371
# INFO:algorithms:Test Accuracy score = 0.799403861554
# INFO:algorithms:Created classifier with min_samples_split = 76 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.860526777106
# INFO:algorithms:Test Accuracy score = 0.795978289883
# INFO:algorithms:Created classifier with min_samples_split = 78 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.859146288018
# INFO:algorithms:Test Accuracy score = 0.800249132485
# INFO:algorithms:Created classifier with min_samples_split = 80 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.861994916294
# INFO:algorithms:Test Accuracy score = 0.798914494172
# INFO:algorithms:Created classifier with min_samples_split = 82 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.857765798931
# INFO:algorithms:Test Accuracy score = 0.796957024646
# INFO:algorithms:Created classifier with min_samples_split = 84 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.856275747217
# INFO:algorithms:Test Accuracy score = 0.798069223241
# INFO:algorithms:Created classifier with min_samples_split = 86 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.855114383382
# INFO:algorithms:Test Accuracy score = 0.797846783522
# INFO:algorithms:Created classifier with min_samples_split = 88 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.855925146814
# INFO:algorithms:Test Accuracy score = 0.801583770798
# INFO:algorithms:Created classifier with min_samples_split = 90 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.854478920151
# INFO:algorithms:Test Accuracy score = 0.800960939585
# INFO:algorithms:Created classifier with min_samples_split = 92 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.854325532474
# INFO:algorithms:Test Accuracy score = 0.801583770798
# INFO:algorithms:Created classifier with min_samples_split = 94 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.851783679551
# INFO:algorithms:Test Accuracy score = 0.802340065842
# INFO:algorithms:Created classifier with min_samples_split = 96 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.854106407222
# INFO:algorithms:Test Accuracy score = 0.799626301272
# INFO:algorithms:Created classifier with min_samples_split = 98 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.85215619248
# INFO:algorithms:Test Accuracy score = 0.801939674348
# INFO:algorithms:Created classifier with min_samples_split = 100 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.851674116925
# INFO:algorithms:Test Accuracy score = 0.801939674348
# INFO:algorithms:Created classifier with min_samples_split = 102 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.851433079148
# INFO:algorithms:Test Accuracy score = 0.802918409111
# INFO:algorithms:Created classifier with min_samples_split = 104 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.851783679551
# INFO:algorithms:Test Accuracy score = 0.800605036035
# INFO:algorithms:Created classifier with min_samples_split = 106 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.851498816724
# INFO:algorithms:Test Accuracy score = 0.805142806299
# INFO:algorithms:Created classifier with min_samples_split = 108 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.848781663599
# INFO:algorithms:Test Accuracy score = 0.802918409111
# INFO:algorithms:Created classifier with min_samples_split = 110 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.851367341572
# INFO:algorithms:Test Accuracy score = 0.802251089955
# INFO:algorithms:Created classifier with min_samples_split = 112 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.849548601981
# INFO:algorithms:Test Accuracy score = 0.807856570869
# INFO:algorithms:Created classifier with min_samples_split = 114 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.847466912087
# INFO:algorithms:Test Accuracy score = 0.801539282854
# INFO:algorithms:Created classifier with min_samples_split = 116 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.847664124814
# INFO:algorithms:Test Accuracy score = 0.8072782276
# INFO:algorithms:Created classifier with min_samples_split = 118 and max depth None
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.845122271891
# INFO:algorithms:Test Accuracy score = 0.809547112732
# INFO:algorithms:Performed evaluation of the min sample split choice
# INFO:algorithms:                  training_score  test_score
# min_sample_split
# 2                       1.000000    0.758430
# 4                       0.984574    0.761278
# 6                       0.971996    0.761634
# 8                       0.958279    0.757051
# 10                      0.945197    0.759899
# 12                      0.938075    0.763947
# 14                      0.929529    0.765860
# 16                      0.924073    0.766750
# 18                      0.915878    0.770353
# 20                      0.910969    0.772667
# 22                      0.906587    0.774847
# 24                      0.902095    0.775425
# 26                      0.901372    0.775870
# 28                      0.895521    0.775202
# 30                      0.894338    0.783032
# 32                      0.891073    0.781164
# 34                      0.887874    0.782765
# 36                      0.884784    0.786324
# 38                      0.882965    0.788193
# 40                      0.881168    0.787348
# 42                      0.881585    0.792953
# 44                      0.877356    0.785346
# 46                      0.877180    0.781386
# 48                      0.876698    0.789083
# 50                      0.876041    0.787259
# 52                      0.870694    0.788860
# 54                      0.870168    0.786369
# 56                      0.868525    0.794199
# 58                      0.869664    0.795489
# 60                      0.867035    0.791796
# 62                      0.868963    0.787437
# 64                      0.865742    0.798158
# 66                      0.865304    0.795133
# 68                      0.864077    0.794154
# 70                      0.861754    0.796913
# 72                      0.860330    0.796423
# 74                      0.859453    0.799404
# 76                      0.860527    0.795978
# 78                      0.859146    0.800249
# 80                      0.861995    0.798914
# 82                      0.857766    0.796957
# 84                      0.856276    0.798069
# 86                      0.855114    0.797847
# 88                      0.855925    0.801584
# 90                      0.854479    0.800961
# 92                      0.854326    0.801584
# 94                      0.851784    0.802340
# 96                      0.854106    0.799626
# 98                      0.852156    0.801940
# 100                     0.851674    0.801940
# 102                     0.851433    0.802918
# 104                     0.851784    0.800605
# 106                     0.851499    0.805143
# 108                     0.848782    0.802918
# 110                     0.851367    0.802251
# 112                     0.849549    0.807857
# 114                     0.847467    0.801539
# 116                     0.847664    0.807278
# 118                     0.845122    0.809547

# %%
df.plot(title='Accuracy change as a function of min_samples_split')

# %%
pd.rolling_mean(df, 5).plot()

# %%
df
# Out:
#                   training score  test score     error
# min_sample_split
# 118                     0.860045    0.812750  0.002237
# 116                     0.856100    0.813684  0.001799
# 114                     0.858314    0.811327  0.002208
# 112                     0.859234    0.815197  0.001939
# 110                     0.860877    0.812038  0.002385
# 108                     0.860899    0.805098  0.003114
# 106                     0.860023    0.805632  0.002958
# 104                     0.860417    0.814352  0.002122
# 102                     0.861206    0.810170  0.002605
# 100                     0.860855    0.807723  0.002823
# 98                      0.861688    0.809770  0.002696
# 96                      0.861447    0.805766  0.003100
# 94                      0.862828    0.808969  0.002901
# 92                      0.863792    0.807189  0.003204
# 90                      0.865172    0.811015  0.002933
# 88                      0.864120    0.809547  0.002978
# 86                      0.866618    0.807723  0.003469
# 84                      0.867495    0.807590  0.003589
# 82                      0.868744    0.806077  0.003927
# 80                      0.865961    0.807189  0.003454
# 78                      0.873105    0.804031  0.004771
# 76                      0.867889    0.809592  0.003399
# 74                      0.872184    0.805944  0.004388
# 72                      0.870935    0.805098  0.004334
# 70                      0.871352    0.808969  0.003892
# 68                      0.873411    0.803141  0.004938
# 66                      0.873389    0.807100  0.004394
# 64                      0.875756    0.803274  0.005254
# 62                      0.878188    0.805454  0.005290
# 60                      0.875515    0.802785  0.005290
# 58                      0.879065    0.806789  0.005224
# 56                      0.880095    0.804787  0.005671
# 54                      0.879306    0.800738  0.006173
# 52                      0.882023    0.801317  0.006513
# 50                      0.882593    0.795889  0.007517
# 48                      0.884740    0.795756  0.007918
# 46                      0.887896    0.797357  0.008197
# 44                      0.889802    0.796334  0.008736
# 42                      0.890065    0.799715  0.008163
# 40                      0.894535    0.797491  0.009418
# 38                      0.891752    0.802207  0.008018
# 36                      0.894886    0.791618  0.010664
# 34                      0.898238    0.792197  0.011245
# 32                      0.903103    0.790640  0.012648
# 30                      0.902511    0.791796  0.012258
# 28                      0.908428    0.792330  0.013479
# 26                      0.911605    0.787348  0.015440
# 24                      0.914234    0.785257  0.016635
# 22                      0.917543    0.785924  0.017324
# 20                      0.922276    0.785168  0.018799
# 18                      0.925738    0.777827  0.021878
# 16                      0.933627    0.778939  0.023928
# 14                      0.939675    0.777026  0.026454
# 12                      0.946599    0.769019  0.031535
# 10                      0.955496    0.775825  0.032281
# 8                       0.964458    0.770843  0.037487
# 6                       0.977934    0.771821  0.042482
# 4                       0.988474    0.767195  0.048965
# 2                       1.000000    0.765815  0.054842

# %%
dt.clf
# Out:
# DecisionTreeClassifier(compute_importances=None, criterion='gini',
#             max_depth=None, max_features=None, max_leaf_nodes=None,
#             min_density=None, min_samples_leaf=1, min_samples_split=40,
#             random_state=None, splitter='best')

# %%
estimate_best_max_depth()
# Out:
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 2
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.891138574809
# INFO:algorithms:Test Accuracy score = 0.791529495507
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 4
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.89122622491
# INFO:algorithms:Test Accuracy score = 0.795666874277
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 6
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.8928696643
# INFO:algorithms:Test Accuracy score = 0.796245217546
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 8
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.890963274608
# INFO:algorithms:Test Accuracy score = 0.798158199128
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 10
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.892957314401
# INFO:algorithms:Test Accuracy score = 0.794688139514
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 12
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.891291962486
# INFO:algorithms:Test Accuracy score = 0.79664560904
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 14
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.890371636427
# INFO:algorithms:Test Accuracy score = 0.802873921167
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 16
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.894250153388
# INFO:algorithms:Test Accuracy score = 0.798069223241
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 18
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.890831799457
# INFO:algorithms:Test Accuracy score = 0.80349675238
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 20
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.890787974406
# INFO:algorithms:Test Accuracy score = 0.794910579233
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 22
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.889363660268
# INFO:algorithms:Test Accuracy score = 0.796734584927
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 24
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.891072837234
# INFO:algorithms:Test Accuracy score = 0.798158199128
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 26
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.891007099658
# INFO:algorithms:Test Accuracy score = 0.797401904084
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 28
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.889999123499
# INFO:algorithms:Test Accuracy score = 0.795177506896
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 30
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.891007099658
# INFO:algorithms:Test Accuracy score = 0.794243260077
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 32
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.891467262687
# INFO:algorithms:Test Accuracy score = 0.797090488478
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 34
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.892365676221
# INFO:algorithms:Test Accuracy score = 0.795889313996
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 36
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.890875624507
# INFO:algorithms:Test Accuracy score = 0.80042708426
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 38
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.893614690157
# INFO:algorithms:Test Accuracy score = 0.797401904084
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 40
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.888947322289
# INFO:algorithms:Test Accuracy score = 0.797268440253
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 42
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.892694364099
# INFO:algorithms:Test Accuracy score = 0.79464365157
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 44
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.893548952581
# INFO:algorithms:Test Accuracy score = 0.798113711184
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 46
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.891664475414
# INFO:algorithms:Test Accuracy score = 0.794821603345
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 48
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.889692348146
# INFO:algorithms:Test Accuracy score = 0.800249132485
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 50
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.890108686125
# INFO:algorithms:Test Accuracy score = 0.792730669988
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 52
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.890744149356
# INFO:algorithms:Test Accuracy score = 0.798825518285
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 54
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.893110702077
# INFO:algorithms:Test Accuracy score = 0.793976332414
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 56
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.893066877027
# INFO:algorithms:Test Accuracy score = 0.793753892695
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 58
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.890722236831
# INFO:algorithms:Test Accuracy score = 0.801850698461
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 60
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.891598737839
# INFO:algorithms:Test Accuracy score = 0.797179464365
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 62
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.890766061881
# INFO:algorithms:Test Accuracy score = 0.792330278495
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 64
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.891029012183
# INFO:algorithms:Test Accuracy score = 0.799492837441
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 66
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.894184415812
# INFO:algorithms:Test Accuracy score = 0.797179464365
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 68
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.890831799457
# INFO:algorithms:Test Accuracy score = 0.801583770798
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 70
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.890766061881
# INFO:algorithms:Test Accuracy score = 0.796156241659
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 72
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.891949338242
# INFO:algorithms:Test Accuracy score = 0.79393184447
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 74
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.891752125515
# INFO:algorithms:Test Accuracy score = 0.795177506896
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 76
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.890809886931
# INFO:algorithms:Test Accuracy score = 0.802918409111
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 78
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.894732228942
# INFO:algorithms:Test Accuracy score = 0.796067265771
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 80
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.892979226926
# INFO:algorithms:Test Accuracy score = 0.796957024646
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 82
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.892628626523
# INFO:algorithms:Test Accuracy score = 0.794109796245
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 84
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.893088789552
# INFO:algorithms:Test Accuracy score = 0.795266482783
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 86
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.892738189149
# INFO:algorithms:Test Accuracy score = 0.791396031675
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 88
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.889626610571
# INFO:algorithms:Test Accuracy score = 0.799225909778
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 90
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.895367692173
# INFO:algorithms:Test Accuracy score = 0.795844826052
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 92
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.890941362083
# INFO:algorithms:Test Accuracy score = 0.798336150903
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 94
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.891533000263
# INFO:algorithms:Test Accuracy score = 0.795044043064
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 96
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.893636602682
# INFO:algorithms:Test Accuracy score = 0.79250823027
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 98
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.892168463494
# INFO:algorithms:Test Accuracy score = 0.792775157932
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 100
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.892256113595
# INFO:algorithms:Test Accuracy score = 0.791707447282
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 102
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.892343763695
# INFO:algorithms:Test Accuracy score = 0.801672746686
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 104
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.891642562889
# INFO:algorithms:Test Accuracy score = 0.796734584927
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 106
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.892343763695
# INFO:algorithms:Test Accuracy score = 0.795889313996
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 108
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.892913489351
# INFO:algorithms:Test Accuracy score = 0.792374766438
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 110
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.892453326321
# INFO:algorithms:Test Accuracy score = 0.801806210517
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 112
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.89341747743
# INFO:algorithms:Test Accuracy score = 0.797268440253
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 114
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.893220264703
# INFO:algorithms:Test Accuracy score = 0.794332235964
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 116
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.887851696029
# INFO:algorithms:Test Accuracy score = 0.800471572204
# INFO:algorithms:Loaded higgs training dataset of size 68114
# INFO:algorithms:Created classifier with min_samples_split = 40 and max depth 118
# INFO:algorithms:Trained decision tree classifier
# INFO:algorithms:Generated predictions
# INFO:algorithms:Training Accuracy score = 0.890196336226
# INFO:algorithms:Test Accuracy score = 0.79935937361
# INFO:algorithms:Performed evaluation of the max death
# INFO:algorithms:           training_score  test_score
# max_depth
# 2                0.891139    0.791529
# 4                0.891226    0.795667
# 6                0.892870    0.796245
# 8                0.890963    0.798158
# 10               0.892957    0.794688
# 12               0.891292    0.796646
# 14               0.890372    0.802874
# 16               0.894250    0.798069
# 18               0.890832    0.803497
# 20               0.890788    0.794911
# 22               0.889364    0.796735
# 24               0.891073    0.798158
# 26               0.891007    0.797402
# 28               0.889999    0.795178
# 30               0.891007    0.794243
# 32               0.891467    0.797090
# 34               0.892366    0.795889
# 36               0.890876    0.800427
# 38               0.893615    0.797402
# 40               0.888947    0.797268
# 42               0.892694    0.794644
# 44               0.893549    0.798114
# 46               0.891664    0.794822
# 48               0.889692    0.800249
# 50               0.890109    0.792731
# 52               0.890744    0.798826
# 54               0.893111    0.793976
# 56               0.893067    0.793754
# 58               0.890722    0.801851
# 60               0.891599    0.797179
# 62               0.890766    0.792330
# 64               0.891029    0.799493
# 66               0.894184    0.797179
# 68               0.890832    0.801584
# 70               0.890766    0.796156
# 72               0.891949    0.793932
# 74               0.891752    0.795178
# 76               0.890810    0.802918
# 78               0.894732    0.796067
# 80               0.892979    0.796957
# 82               0.892629    0.794110
# 84               0.893089    0.795266
# 86               0.892738    0.791396
# 88               0.889627    0.799226
# 90               0.895368    0.795845
# 92               0.890941    0.798336
# 94               0.891533    0.795044
# 96               0.893637    0.792508
# 98               0.892168    0.792775
# 100              0.892256    0.791707
# 102              0.892344    0.801673
# 104              0.891643    0.796735
# 106              0.892344    0.795889
# 108              0.892913    0.792375
# 110              0.892453    0.801806
# 112              0.893417    0.797268
# 114              0.893220    0.794332
# 116              0.887852    0.800472
# 118              0.890196    0.799359
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-d23fc737492b> in <module>()
# ----> 1 estimate_best_max_depth()
#
# /Users/maestro/schoolspace/bag-of-algorithms/algorithms/decision_tree.py in estimate_best_max_depth()
#      85     LOGGER.info(df)
#      86     # plot the accuracy curve
# ---> 87     df['error'] = (df['training_score'] - df['test score']) * (df['training_score'] - df['test_score'])
#      88     smooth_df = pd.rolling_mean(df, 5)
#      89     smooth_df = smooth_df[['training_score', 'test_score']]
#
# /Users/maestro/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1682             return self._getitem_multilevel(key)
#    1683         else:
# -> 1684             return self._getitem_column(key)
#    1685
#    1686     def _getitem_column(self, key):
#
# /Users/maestro/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1689         # get column
#    1690         if self.columns.is_unique:
# -> 1691             return self._get_item_cache(key)
#    1692
#    1693         # duplicate columns & possible reduce dimensionaility
#
# /Users/maestro/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1050         res = cache.get(item)
#    1051         if res is None:
# -> 1052             values = self._data.get(item)
#    1053             res = self._box_item_values(item, values)
#    1054             cache[item] = res
#
# /Users/maestro/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item)
#    2535
#    2536             if not isnull(item):
# -> 2537                 loc = self.items.get_loc(item)
#    2538             else:
#    2539                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/maestro/anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key)
#    1154         loc : int if unique index, possibly slice or mask if not
#    1155         """
# -> 1156         return self._engine.get_loc(_values_from_object(key))
#    1157
#    1158     def get_value(self, series, key):
#
# /Users/maestro/anaconda/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:3353)()
#
# /Users/maestro/anaconda/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:3233)()
#
# /Users/maestro/anaconda/lib/python2.7/site-packages/pandas/hashtable.so in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12299)()
#
# /Users/maestro/anaconda/lib/python2.7/site-packages/pandas/hashtable.so in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12250)()
#
# KeyError: 'test score'

# %%
# %matplotlib inline
from sklearn.tree import DecisionTreeClassifier
from sklearn.cross_validation import cross_val_score

# %%
from algo_evaluation.datasets import *

# %%
higgs_data = load_higgs_train(sample_size=10000)
features, weights, labels = higgs_data
print 'Size of the dataset:', features.shape[0]
print 'Number of features:', features.shape[1]
print 'Number of positives (signal):', labels.value_counts()['s']
print 'Number of negatives (background):', labels.value_counts()['b']
# Out:
# Size of the dataset: 2768
# Number of features: 13
# Number of positives (signal): 1270
# Number of negatives (background): 1498

# %%
from algo_evaluation.optimization import hill_climbing as hc

# %%
max_depth = (10, 100)
min_samples_split = (2, 50)

# %%
domain = [max_depth, min_samples_split]
print domain
# Out:
# [(10, 100), (2, 50)]

# %%
clf = DecisionTreeClassifier()
scores = cross_val_score(clf, features, labels, cv=10)
mean_score = scores.mean()
print mean_score
# Out:
# 0.750732485743

# %%
def compute_classification_error(solution):
    md, ms = solution
    clf = DecisionTreeClassifier(max_depth=md, min_samples_split=ms)
    scores = cross_val_score(clf, features, labels, cv=10)
    mean_score = scores.mean()
    std_score = scores.std()
    return mean_score

# %%
df = hc.hillclimb(domain, compute_classification_error, max_evaluations=1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-d80983ec1f85> in <module>()
# ----> 1 df = hc.hillclimb(domain, compute_classification_error, max_evaluations=1000)
#
# /Users/maestro/schoolspace/bag-of-algorithms/algo_evaluation/optimization/hill_climbing.pyc in hillclimb(domain, costf, max_evaluations)
#      23     best = current
#      24     for j in range(len(neighbors)):
# ---> 25       cost = -1 * costf(neighbors[j])
#      26       if cost > best:
#      27         best=cost
#
# <ipython-input-25-e94f5971487b> in compute_classification_error(solution)
#       2     md, ms = solution
#       3     clf = DecisionTreeClassifier(max_depth=md, min_samples_split=ms)
# ----> 4     scores = cross_val_score(clf, features, labels, cv=10)
#       5     mean_score = scores.mean()
#       6     std_score = scores.std()
#
# /Users/maestro/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.pyc in cross_val_score(estimator, X, y, scoring, cv, n_jobs, verbose, fit_params, score_func, pre_dispatch)
#    1149                                               train, test, verbose, None,
#    1150                                               fit_params)
# -> 1151                       for train, test in cv)
#    1152     return np.array(scores)[:, 0]
#    1153
#
# /Users/maestro/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     651             self._iterating = True
#     652             for function, args, kwargs in iterable:
# --> 653                 self.dispatch(function, args, kwargs)
#     654
#     655             if pre_dispatch == "all" or n_jobs == 1:
#
# /Users/maestro/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch(self, func, args, kwargs)
#     398         """
#     399         if self._pool is None:
# --> 400             job = ImmediateApply(func, args, kwargs)
#     401             index = len(self._jobs)
#     402             if not _verbosity_filter(index, self.verbose):
#
# /Users/maestro/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __init__(self, func, args, kwargs)
#     136         # Don't delay the application, to avoid keeping the input
#     137         # arguments in memory
# --> 138         self.results = func(*args, **kwargs)
#     139
#     140     def get(self):
#
# /Users/maestro/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.pyc in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters)
#    1237         estimator.fit(X_train, **fit_params)
#    1238     else:
# -> 1239         estimator.fit(X_train, y_train, **fit_params)
#    1240     test_score = _score(estimator, X_test, y_test, scorer)
#    1241     if return_train_score:
#
# /Users/maestro/anaconda/lib/python2.7/site-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_mask, X_argsorted, check_input, sample_weight)
#     206                              "number of samples=%d" % (len(y), n_samples))
#     207         if self.min_samples_split <= 0:
# --> 208             raise ValueError("min_samples_split must be greater than zero.")
#     209         if self.min_samples_leaf <= 0:
#     210             raise ValueError("min_samples_leaf must be greater than zero.")
#
# ValueError: min_samples_split must be greater than zero.

# %%
df.optimal_value.plot()

# %%
df.cost.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-0bc8bd013d51> in <module>()
# ----> 1 df.cost.plot()
#
# /Users/maestro/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1945                 return self[name]
#    1946             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1947                                  (type(self).__name__, name))
#    1948
#    1949     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'cost'

# %%
from algo_evaluation.optimization.problems import hyper_optimization

# %%
rhc_df, sa_df = hyper_optimization.compare_all((features, labels))

# %%
domain

# %%
from algo_evaluation.optimization.mimic import Mimic

# %%
m = Mimic(domain, compute_classification_error)

# %%
m.fit()

# %%
import seaborn as sns
sns.set_context(rc={'lines.markeredgewidth': 0.1})
tips = sns.load_dataset("tips")

# %%
sns.regplot("total_bill", "tip", tips);

# %%
# %matplotlib inline
import matplotlib
import seaborn as sns
matplotlib.style.use('ggplot')

# %%
from algo_evaluation.datasets import *
from algo_evaluation.handle_imports import *

# %%
lepton_data = load_lepton_data(sample_size=None, verbose=False)

# %%
df = lepton_data[0]

# %%
features = df.columns
len(features)
# Out:
# 49

# %%
pca_rank = pca_eval.rank_features(lepton_data, n_components=49, display=True)

# %%
pca_rank
# Out:
#                      variance_ratio     time algo
# feature
# LifeTime               6.037747e-01  0.07388  pca
# dira                   3.375777e-01  0.07388  pca
# FlightDistance         5.280504e-02  0.07388  pca
# FlightDistanceError    5.286642e-03  0.07388  pca
# IP                     4.472039e-04  0.07388  pca
# IPSig                  9.126972e-05  0.07388  pca
# VertexChi2             7.586893e-06  0.07388  pca
# pt                     6.106652e-06  0.07388  pca
# DOCAone                3.528782e-06  0.07388  pca
# DOCAtwo                1.344807e-07  0.07388  pca
# DOCAthree              4.830617e-08  0.07388  pca
# IP_p0p2                3.378368e-08  0.07388  pca
# IP_p1p2                2.610258e-08  0.07388  pca
# isolationa             8.392443e-09  0.07388  pca
# isolationb             7.845973e-09  0.07388  pca
# isolationc             6.799362e-09  0.07388  pca
# isolationd             2.533127e-09  0.07388  pca
# isolatione             2.142625e-09  0.07388  pca
# isolationf             2.012722e-09  0.07388  pca
# iso                    1.833917e-10  0.07388  pca
# CDF1                   1.555067e-10  0.07388  pca
# CDF2                   1.113372e-10  0.07388  pca
# CDF3                   8.845138e-11  0.07388  pca
# ISO_SumBDT             6.618904e-11  0.07388  pca
# p0_IsoBDT              6.400921e-11  0.07388  pca
# p1_IsoBDT              4.593553e-11  0.07388  pca
# p2_IsoBDT              3.510982e-11  0.07388  pca
# p0_track_Chi2Dof       2.970181e-11  0.07388  pca
# p1_track_Chi2Dof       2.909337e-11  0.07388  pca
# p2_track_Chi2Dof       2.313849e-11  0.07388  pca
# p0_IP                  1.936786e-11  0.07388  pca
# p1_IP                  1.875181e-11  0.07388  pca
# p2_IP                  9.815190e-12  0.07388  pca
# p0_IPSig               9.079164e-12  0.07388  pca
# p1_IPSig               6.596705e-12  0.07388  pca
# p2_IPSig               5.387383e-12  0.07388  pca
# p0_pt                  3.510251e-12  0.07388  pca
# p1_pt                  2.437097e-12  0.07388  pca
# p2_pt                  2.079065e-12  0.07388  pca
# p0_p                   1.754914e-12  0.07388  pca
# p1_p                   1.609248e-12  0.07388  pca
# p2_p                   1.134461e-12  0.07388  pca
# p0_eta                 7.668028e-13  0.07388  pca
# p1_eta                 4.677608e-13  0.07388  pca
# p2_eta                 7.920242e-14  0.07388  pca
# SPDhits                2.547710e-16  0.07388  pca
# production             2.199237e-17  0.07388  pca
# mass                   6.822305e-33  0.07388  pca
# min_ANNmuon            6.822305e-33  0.07388  pca

# %%
ica_comp = ica_eval.estimate_components(lepton_data, display=True)

# %%
ica_comp
# Out:
# DOCAone                5160.870486
# dira                    100.323725
# p1_IsoBDT                83.082651
# p2_IsoBDT                80.951339
# p0_IsoBDT                74.610004
# DOCAthree                57.181453
# FlightDistance           42.390006
# p2_IP                    37.632086
# p0_pt                    28.057501
# p0_IP                    25.264325
# p1_pt                    23.430980
# p2_p                     23.330285
# p0_p                     22.386928
# p1_IP                    21.916421
# pt                       21.554930
# LifeTime                 21.506433
# IP_p0p2                  20.989222
# p2_pt                    20.703902
# p1_p                     20.228865
# DOCAtwo                  19.267818
# IP_p1p2                  14.199772
# p1_IPSig                 12.757845
# p0_IPSig                 11.927243
# FlightDistanceError      11.477193
# IP                       10.945316
# p2_IPSig                 10.773748
# isolationd               10.628797
# isolatione               10.397175
# isolationf                9.687989
# iso                       8.839678
# isolationa                5.605452
# isolationc                5.126514
# isolationb                4.589902
# p1_track_Chi2Dof          3.134648
# p2_track_Chi2Dof          2.985975
# p0_track_Chi2Dof          2.616191
# ISO_SumBDT                2.514593
# mass                      1.075061
# IPSig                    -0.248250
# VertexChi2               -0.370136
# p0_eta                   -0.388842
# SPDhits                  -0.462740
# CDF1                     -0.487601
# p2_eta                   -0.509856
# p1_eta                   -0.562896
# CDF3                     -0.706393
# CDF2                     -0.761843
# min_ANNmuon              -1.127297
# production               -1.767652
# dtype: float64
